# %%
from pathlib import Path
import csv
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %%
# Path for whale returns
file_path = Path("whale_returns.csv")
df_combined_returns = pd.read_csv(file_path)
df_combined_returns = df_combined_returns.set_index('Date')

# %%
combined_returns = pd.concat([df_combined_returns, csv_combined_returns])
combined_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                        NaN                 NaN
# 2019-04-26                        NaN                 NaN
# 2019-04-29                        NaN                 NaN
# 2019-04-30                        NaN                 NaN
# 2019-05-01                        NaN                 NaN
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN       NaN
# 2015-03-03                    -0.000496               -0.006569       NaN
# ...

# %%
df_combined_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
df_combined_returns.count()
# Out:
# SOROS FUND MANAGEMENT LLC      1059
# PAULSON & CO.INC.              1059
# TIGER GLOBAL MANAGEMENT LLC    1059
# BERKSHIRE HATHAWAY INC         1059
# dtype: int64

# %%
# Path for algorithmic
csv_algorithmic = Path("algo_returns.csv")
csv_combined_returns = pd.read_csv(csv_algorithmic)
csv_combined_returns = csv_combined_returns.set_index('Date')

# %%
csv_combined_returns.count()
# Out:
# Algo 1    1241
# Algo 2    1235
# dtype: int64

# %%
csv_combined_returns.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Path for sp500
csv_sp500 = Path("sp500_history.csv")
sp500_data = pd.read_csv(csv_sp500)
sp500_data = sp500_data.set_index('Date')

# %%
sp500_data.head()
# Out:
#               Close
# Date
# 23-Apr-19  $2933.68
# 22-Apr-19  $2907.97
# 18-Apr-19  $2905.03
# 17-Apr-19  $2900.45
# 16-Apr-19  $2907.06

# %%
sp500_data.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_data["Close"] = sp500_data["Close"].str.replace("$", "")
sp500_data["Close"] = sp500_data["Close"].str.replace(",", "")
sp500_data["Close"] = sp500_data["Close"].astype("float")
sp500_data.dtypes
# Out:
# C:\Users\withn\AppData\Local\Temp/ipykernel_19944/2742832925.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp500_data["Close"] = sp500_data["Close"].str.replace("$", "")
# Close    float64
# dtype: object

# %%
sp500_returns = sp500_data.pct_change()
sp500_returns.head()
# Out:
#               Close
# Date
# 23-Apr-19       NaN
# 22-Apr-19 -0.008764
# 18-Apr-19 -0.001011
# 17-Apr-19 -0.001577
# 16-Apr-19  0.002279

# %%
sp500_returns = sp500_returns.dropna().copy
sp500_returns.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19944/3535798373.py in <module>
#       1 sp500_returns = sp500_returns.dropna().copy
# ----> 2 sp500_returns.head()
#
# AttributeError: 'function' object has no attribute 'head'

# %%
sp500_data = sp500_data.rename(columns={"close": "column"})
sp500_data.head()
# Out:
#              Close
# Date
# 23-Apr-19  2933.68
# 22-Apr-19  2907.97
# 18-Apr-19  2905.03
# 17-Apr-19  2900.45
# 16-Apr-19  2907.06

# %%
csv_returns = csv_combined_returns.pct_change()
df_returns = df_combined_returns.pct_change()

# %%
combined_data = pd.concat([combined_returns,sp500_data])
combined_data
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 5-Oct-12                          NaN                 NaN
# 4-Oct-12                          NaN                 NaN
# 3-Oct-12                          NaN                 NaN
# 2-Oct-12                          NaN                 NaN
# 1-Oct-12                          NaN                 NaN
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN     NaN
# 2015-03-03                    -0.000496               -0.006569     NaN
# ...

# %%
portfolio_data = combined_data.pct_change()

# %%
cumulative_profit = combined_data 
cumulative_profit.plot.box()
# Out:
# <AxesSubplot:>

# %%
company_returns = combined_data.pct_change()
company_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                        NaN                 NaN
# 2015-03-04                  -2.762070           -1.650792
# 2015-03-05                   0.800968            0.257544
# 2015-03-06                  -2.968465           -1.876837
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN     NaN
# 2015-03-03                          NaN                     NaN     NaN
# 2015-03-04                     4.113646               -1.641381     NaN
# 2015-03-05                    -1.929234                0.596558     NaN
# 2015-03-06                    -4.601872               -2.947282     NaN
#
#             Algo 2  Close
# Date
# 2015-03-02     NaN    NaN
# 2015-03-03     NaN    NaN
# 2015-03-04     NaN    NaN
# 2015-03-05     NaN    NaN
# ...

# %%
daily_returns = sp500_data.pct_change()
daily_returns.head()
# Out:
#               Close
# Date
# 23-Apr-19       NaN
# 22-Apr-19 -0.008764
# 18-Apr-19 -0.001011
# 17-Apr-19 -0.001577
# 16-Apr-19  0.002279

# %%
volatility = combined_data.std() * np.sqrt(252)
volatility.sort_values(inplace=True)
volatility
# Out:
# PAULSON & CO.INC.                 0.110754
# SOROS FUND MANAGEMENT LLC         0.124487
# Algo 1                            0.126558
# Algo 2                            0.134401
# TIGER GLOBAL MANAGEMENT LLC       0.171830
# BERKSHIRE HATHAWAY INC            0.203682
# Close                          6383.488916
# dtype: float64

# %%
stocks = combined_data.rolling(window=21).mean()
stocks
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                        NaN                 NaN
# 2015-03-04                        NaN                 NaN
# 2015-03-05                        NaN                 NaN
# 2015-03-06                        NaN                 NaN
# ...                               ...                 ...
# 5-Oct-12                          NaN                 NaN
# 4-Oct-12                          NaN                 NaN
# 3-Oct-12                          NaN                 NaN
# 2-Oct-12                          NaN                 NaN
# 1-Oct-12                          NaN                 NaN
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN     NaN
# 2015-03-03                          NaN                     NaN     NaN
# ...

# %%
stocks.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stocks = combined_data.corr()

# %%
sns.heatmap(combined_data, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:ylabel='Date'>

# %%
covariance = daily_returns['SOROS FUND MANAGEMENT LLC']
covariance
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SOROS FUND MANAGEMENT LLC'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
