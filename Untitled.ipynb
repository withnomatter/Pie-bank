# %%
from pathlib import Path
import csv
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %%
# Path for whale returns
file_path = Path("whale_returns.csv")
df_combined_returns = pd.read_csv(file_path)
df_combined_returns = df_combined_returns.set_index('Date')

# %%
combined_returns = pd.concat([df_combined_returns, csv_combined_returns])
combined_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                        NaN                 NaN
# 2019-04-26                        NaN                 NaN
# 2019-04-29                        NaN                 NaN
# 2019-04-30                        NaN                 NaN
# 2019-05-01                        NaN                 NaN
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN       NaN
# 2015-03-03                    -0.000496               -0.006569       NaN
# 2015-03-04                    -0.002534                0.004213       NaN
# 2015-03-05                     0.002355                0.006726       NaN
# 2015-03-06                    -0.008481               -0.013098       NaN
# ...                                 ...                     ...       ...
# 2019-04-25                          NaN                     NaN  0.000682
# 2019-04-26                          NaN                     NaN  0.002981
# 2019-04-29                          NaN                     NaN  0.005208
# 2019-04-30                          NaN                     NaN -0.002944
# 2019-05-01                          NaN                     NaN  0.000094
#
#               Algo 2
# Date
# 2015-03-02       NaN
# 2015-03-03       NaN
# 2015-03-04       NaN
# 2015-03-05       NaN
# 2015-03-06       NaN
# ...              ...
# 2019-04-25 -0.007247
# 2019-04-26  0.005256
# 2019-04-29  0.002829
# 2019-04-30 -0.001570
# 2019-05-01 -0.007358
#
# [2301 rows x 6 columns]

# %%
df_combined_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
df_combined_returns.count()
# Out:
# SOROS FUND MANAGEMENT LLC      1059
# PAULSON & CO.INC.              1059
# TIGER GLOBAL MANAGEMENT LLC    1059
# BERKSHIRE HATHAWAY INC         1059
# dtype: int64

# %%
# Path for algorithmic
csv_algorithmic = Path("algo_returns.csv")
csv_combined_returns = pd.read_csv(csv_algorithmic)
csv_combined_returns = csv_combined_returns.set_index('Date')

# %%
csv_combined_returns.count()
# Out:
# Algo 1    1241
# Algo 2    1235
# dtype: int64

# %%
csv_combined_returns.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Path for sp500
csv_sp500 = Path("sp500_history.csv")
sp500_data = pd.read_csv(csv_sp500)
sp500_data = sp500_data.set_index('Date')

# %%
sp500_data.head()
# Out:
#               Close
# Date
# 23-Apr-19  $2933.68
# 22-Apr-19  $2907.97
# 18-Apr-19  $2905.03
# 17-Apr-19  $2900.45
# 16-Apr-19  $2907.06

# %%
sp500_data.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_data["Close"] = sp500_data["Close"].str.replace("$", "")
sp500_data["Close"] = sp500_data["Close"].str.replace(",", "")
sp500_data["Close"] = sp500_data["Close"].astype("float")
sp500_data.dtypes
# Out:
# C:\Users\withn\AppData\Local\Temp/ipykernel_5560/2742832925.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp500_data["Close"] = sp500_data["Close"].str.replace("$", "")
# Close    float64
# dtype: object

# %%
sp500_returns = sp500_data.pct_change()
sp500_returns.head()
# Out:
#               Close
# Date
# 23-Apr-19       NaN
# 22-Apr-19 -0.008764
# 18-Apr-19 -0.001011
# 17-Apr-19 -0.001577
# 16-Apr-19  0.002279

# %%
sp500_data = sp500_data.rename(columns={"close": "column"})
sp500_data.head()
# Out:
#              Close
# Date
# 23-Apr-19  2933.68
# 22-Apr-19  2907.97
# 18-Apr-19  2905.03
# 17-Apr-19  2900.45
# 16-Apr-19  2907.06

# %%
csv_returns = csv_combined_returns.pct_change()
df_returns = df_combined_returns.pct_change()

# %%
combined_data = pd.concat([combined_returns,sp500_data])
combined_data
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 5-Oct-12                          NaN                 NaN
# 4-Oct-12                          NaN                 NaN
# 3-Oct-12                          NaN                 NaN
# 2-Oct-12                          NaN                 NaN
# 1-Oct-12                          NaN                 NaN
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN     NaN
# 2015-03-03                    -0.000496               -0.006569     NaN
# 2015-03-04                    -0.002534                0.004213     NaN
# 2015-03-05                     0.002355                0.006726     NaN
# 2015-03-06                    -0.008481               -0.013098     NaN
# ...                                 ...                     ...     ...
# 5-Oct-12                            NaN                     NaN     NaN
# 4-Oct-12                            NaN                     NaN     NaN
# 3-Oct-12                            NaN                     NaN     NaN
# 2-Oct-12                            NaN                     NaN     NaN
# 1-Oct-12                            NaN                     NaN     NaN
#
#             Algo 2    Close
# Date
# 2015-03-02     NaN      NaN
# 2015-03-03     NaN      NaN
# 2015-03-04     NaN      NaN
# 2015-03-05     NaN      NaN
# 2015-03-06     NaN      NaN
# ...            ...      ...
# 5-Oct-12       NaN  1460.93
# 4-Oct-12       NaN  1461.40
# 3-Oct-12       NaN  1450.99
# 2-Oct-12       NaN  1445.75
# 1-Oct-12       NaN  1444.49
#
# [3950 rows x 7 columns]

# %%
portfolio_data = combined_data.pct_change()

# %%
portfolio_data = portfolio_data.boxplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5560/3361668693.py in <module>
# ----> 1 portfolio_data = portfolio_data.boxplot()
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: boxplot() missing 1 required positional argument: 'x'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5560/3021568550.py in <module>
# ----> 1 portfolio_data.plot.bar(title ='Banking')
#
# AttributeError: 'function' object has no attribute 'bar'
